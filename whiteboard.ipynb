# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
loan = pd.read_csv("Data\loan_df.csv")
filter = ['last_pymnt_d', 'last_credit_pull_d', 'sub_grade', 'zip_code',
       'int_rate', 'revol_bal', 'purpose', 'earliest_cr_line', 'revol_util',
       'term', 'dti', 'last_pymnt_amnt', 'total_rec_int', 'emp_title', 'title',
       'total_pymnt', 'loan_amnt', 'total_rec_prncp', 'annual_inc',
       'total_acc', 'funded_amnt', 'home_ownership', 'open_acc',
       'verification_status', 'emp_length']

loan.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\DAT\AppData\Local\Temp\ipykernel_7292\1146804463.py:1: SyntaxWarning: invalid escape sequence '\l'
#   loan = pd.read_csv("Data\loan_df.csv")
#   last_pymnt_d last_credit_pull_d sub_grade zip_code  int_rate  revol_bal  \
# 0       Jan-15             May-16        B2    860xx     10.65    13648.0
# 1       Apr-13             Sep-13        C4    309xx     15.27     1687.0
# 2       Jun-14             May-16        C5    606xx     15.96     2956.0
# 3       Jan-15             Apr-16        C1    917xx     13.49     5598.0
# 4          NaN                NaN       NaN      NaN      7.90     7963.0
#
#           purpose earliest_cr_line  revol_util        term  ...   total_pymnt  \
# 0     credit_card           Jan-85        83.7   36 months  ...   5863.155187
# 1             car           Apr-99         9.4   60 months  ...   1008.710000
# 2  small_business           Nov-01        98.5   36 months  ...   3005.666844
# 3           other           Feb-96        21.0   36 months  ...  12231.890000
# 4             NaN              NaN        28.3         NaN  ...   5632.210000
#
#    loan_amnt  total_rec_prncp annual_inc total_acc  funded_amnt  \
# 0     5000.0          5000.00    24000.0       9.0       5000.0
# 1     2500.0           456.46    30000.0       4.0       2500.0
# 2     2400.0          2400.00    12252.0      10.0       2400.0
# 3    10000.0         10000.00    49200.0      37.0      10000.0
# 4     5000.0          5000.00    36000.0      12.0       5000.0
#
#    home_ownership  open_acc  verification_status  emp_length
# 0            RENT       3.0             Verified        10.0
# 1            RENT       3.0      Source Verified         1.0
# 2            RENT       2.0         Not Verified        10.0
# 3            RENT      10.0      Source Verified        10.0
# 4             NaN       9.0                  NaN         3.0
#
# [5 rows x 25 columns]

# %%
loan['revol_util']
# Out:
# 0        83.7
# 1         9.4
# 2        98.5
# 3        21.0
# 4        28.3
#          ...
# 36810    23.0
# 36811    13.1
# 36812    26.9
# 36813    19.4
# 36814    51.5
# Name: revol_util, Length: 36815, dtype: float64

# %%
last_credit_pull_d, last_pymnt_d, term, sub_grade = loan.loc[1]
input_data = pd.DataFrame({
    'last_credit_pull_d': [last_credit_pull_d],
    'last_pymnt_d': [last_pymnt_d],
    'term': [term],
    'sub_grade': [sub_grade]
})

# %%
loan= pd.concat([loan,input_data], ignore_index= True)

# %%
input_data
# Out:
#   last_credit_pull_d last_pymnt_d        term sub_grade
# 0             Sep-13       Apr-13   60 months        C4

# %%
loan.head()
# Out:
#   last_credit_pull_d last_pymnt_d        term sub_grade
# 0             May-16       Jan-15   36 months        B2
# 1             Sep-13       Apr-13   60 months        C4
# 2             May-16       Jun-14   36 months        C5
# 3             Apr-16       Jan-15   36 months        C1
# 4                NaN          NaN         NaN       NaN

# %%
label_encoder = LabelEncoder()
for col in loan:
    loan[col] = label_encoder.fit_transform(loan[col])
    input_data[col] = label_encoder.transform(input_data[col])

for col in loan:
    freq_encoding = loan[col].value_counts().to_dict()
    loan[col] = loan[col].map(freq_encoding)
    input_data[col] = input_data[col].map(freq_encoding).fillna(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 4
#       2 for col in loan:
#       3     loan[col] = label_encoder.fit_transform(loan[col])
# ----> 4     input_data[col] = label_encoder.transform(input_data[col])
#       6 for col in loan:
#       7     freq_encoding = loan[col].value_counts().to_dict()
#
# File c:\Users\DAT\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:132, in LabelEncoder.transform(self, y)
#     119 """Transform labels to normalized encoding.
#     120
#     121 Parameters
#    (...)
#     129     Labels as normalized encodings.
#     130 """
#     131 check_is_fitted(self)
# --> 132 y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
#     133 # transform of empty array is empty array
#     134 if _num_samples(y) == 0:
#
# File c:\Users\DAT\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1342, in column_or_1d(y, dtype, warn)
#    1310 """Ravel column or 1d numpy array, else raises an error.
#    1311
#    1312 Parameters
#    (...)
#    1339 array([1, 1])
#    1340 """
#    1341 xp, _ = get_namespace(y)
# -> 1342 y = check_array(
#    1343     y,
#    1344     ensure_2d=False,
#    1345     dtype=dtype,
#    1346     input_name="y",
#    1347     force_all_finite=False,
#    1348     ensure_min_samples=0,
#    1349 )
#    1351 shape = y.shape
#    1352 if len(shape) == 1:
#
# File c:\Users\DAT\anaconda3\Lib\site-packages\sklearn\utils\validation.py:995, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     987     if xp.isdtype(array.dtype, ("real floating", "complex floating")):
#     988         _assert_all_finite(
#     989             array,
#     990             allow_nan=False,
#    (...)
#     993             input_name=input_name,
#     994         )
# --> 995     array = xp.astype(array, dtype, copy=False)
#     996 else:
#     997     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#
# File c:\Users\DAT\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py:290, in _NumPyAPIWrapper.astype(self, x, dtype, copy, casting)
#     288 def astype(self, x, dtype, *, copy=True, casting="unsafe"):
#     289     # astype is not defined in the top level NumPy namespace
# --> 290     return x.astype(dtype, copy=copy, casting=casting)
#
# ValueError: invalid literal for int() with base 10: 'Sep-13'

# %%
loan.head()
# Out:
#    last_credit_pull_d  last_pymnt_d   term  sub_grade
# 0                8722           323  26678       1820
# 1                 370           811   9047       1102
# 2                8722           745  26678       1047
# 3                2230           323  26678       1883
# 4                1092          1161   1091       1091
